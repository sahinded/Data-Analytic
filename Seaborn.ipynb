# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill['manner_of_death']
# Out:
# 0                   shot
# 1                   shot
# 2       shot and Tasered
# 3                   shot
# 4                   shot
#               ...
# 2530                shot
# 2531                shot
# 2532                shot
# 2533                shot
# 2534                shot
# Name: manner_of_death, Length: 2535, dtype: object

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x='gender', y='age', data=kill, hue=kill['manner_of_death']);

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn

# %%
# with seaborn
figure = plt.subplots(figsize=(12,6))
sns.swarmplot(x='gender', y='age', data=kill, hue=kill['manner_of_death']);

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
kill.head(2)
# Out:
#    id              name      date manner_of_death armed   age gender race  \
# 0   3        Tim Elliot  02/01/15            shot   gun  53.0      M    A
# 1   4  Lewis Lee Lembke  02/01/15            shot   gun  47.0      M    W
#
#       city state  signs_of_mental_illness threat_level         flee  \
# 0  Shelton    WA                     True       attack  Not fleeing
# 1    Aloha    OR                    False       attack  Not fleeing
#
#    body_camera
# 0        False
# 1        False

# %%
city_freq = kill['city'].value_counts().head(12)
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Miami            18
# Austin           18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=city_freq.index, y=city_freq.values)
ax.set_title('Most dangerous cities',fontsize=14, color='blue')
ax.set_xticklabels(city_freq.index, rotation=45);

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq = kill.state.value_counts()[:20]
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# NM     51
# PA     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.countplot(x='state', data=kill, order= state_freq.index)
ax.set_title('Most dangerous states',fontsize=15, color='blue')
ax.set_xticklabels(state_freq.index, rotation=45);

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.head(2)
# Out:
#    id              name      date manner_of_death armed   age gender race  \
# 0   3        Tim Elliot  02/01/15            shot   gun  53.0      M    A
# 1   4  Lewis Lee Lembke  02/01/15            shot   gun  47.0      M    W
#
#       city state  signs_of_mental_illness threat_level         flee  \
# 0  Shelton    WA                     True       attack  Not fleeing
# 1    Aloha    OR                    False       attack  Not fleeing
#
#    body_camera
# 0        False
# 1        False

# %%
kill.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
illness = kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn

# %%
sns.countplot(x='signs_of_mental_illness', 
              data=kill, order= illness.index);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot(x='threat_level'
              ,data=kill
              ,order= threads_freq.index);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn

# %%
# with seaborn
sns.countplot(x='flee'
              ,data=kill
              ,order= flee_freq.index);
