# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df = pd.read_csv('adult_eda.csv')

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0] * 100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education-num     2.463
# marital-status    0.000
# occupation        0.000
# relationship     15.565
# race              0.000
# sex               0.000
# capital-gain      0.000
# capital-loss      0.000
# hours-per-week    0.000
# native-country    0.000
# salary            0.000
# dtype: float64

# %%
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df_c=df.copy()

# %%
df_c = df_c.drop_duplicates()

# %%
df_c.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_c.shape
# Out:
# (32537, 15)

# %%
df_c.describe()
# Out:
#             age      fnlwgt  education-num  capital-gain  capital-loss  \
# count 32537.000   32537.000      31735.000     32537.000     32537.000
# mean     38.586  189780.849         10.084      1078.444        87.368
# std      13.638  105556.471          2.575      7387.957       403.102
# min      17.000   12285.000          1.000         0.000         0.000
# 25%      28.000  117827.000          9.000         0.000         0.000
# 50%      37.000  178356.000         10.000         0.000         0.000
# 75%      48.000  236993.000         12.000         0.000         0.000
# max      90.000 1484705.000         16.000     99999.000      4356.000
#
#        hours-per-week
# count       32537.000
# mean           40.440
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %%
df_c.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
dict={'education-num': 'education_num','marital-status': 'marital_status','capital-gain':'capital_gain',
      'capital-loss': 'capital_loss', 'hours-per-week':'hours_per_week', 'native-country':'native_country'}

df_c= df_c.rename(columns=dict)
df_c.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
object_col = df_c.select_dtypes(include='object').columns
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
df_c.describe(include = "O").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df_c[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %%
df_c[df_c == '?'].any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %%
df_c['salary'].value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
ax=sns.countplot(data= df_c, x='salary');

#ax.bar_label(ax.containers[0])

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.3, p.get_height()+20), fontsize=14)

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.pie(df_c['salary'].value_counts().values, data=df_c, labels=df_c['salary'].value_counts().index
        ,shadow=True
        , autopct='%.1f%%'
        ,colors=['LightSkyBlue', 'gold']
        ,explode=[0,0.1]
        ,radius=1
        ,textprops={'fontsize':16}
       );

ax.axis('equal')
plt.title('Percentage of Income-Levels', fontsize=14);

# %% [markdown]
# # Numeric Features

# %%
df_c.describe()
# Out:
#             age      fnlwgt  education_num  capital_gain  capital_loss  \
# count 32537.000   32537.000      31735.000     32537.000     32537.000
# mean     38.586  189780.849         10.084      1078.444        87.368
# std      13.638  105556.471          2.575      7387.957       403.102
# min      17.000   12285.000          1.000         0.000         0.000
# 25%      28.000  117827.000          9.000         0.000         0.000
# 50%      37.000  178356.000         10.000         0.000         0.000
# 75%      48.000  236993.000         12.000         0.000         0.000
# max      90.000 1484705.000         16.000     99999.000      4356.000
#
#        hours_per_week
# count       32537.000
# mean           40.440
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %% [markdown]
# # age

# %%
sns.boxplot(x='age', data=df_c);

# %%
sns.histplot(df_c.age, bins=20, kde=True);

# %%
df_c['age'].describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.boxplot(x='salary', y='age', data=df_c)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
ax, fig = plt.subplots()

sns.histplot(x='age', data=df_c,kde=True, bins=20, hue= 'salary', alpha=0.4)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
ax, fig = plt.subplots()

sns.kdeplot(x='age', data=df_c, hue= 'salary', alpha=0.2, shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
df_c.groupby('salary')['age'].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# # fnlwgt

# %%
sns.boxplot(x='fnlwgt', data=df_c);

plt.xlim(0)
# Out:
# (0.0, 1558326.0)

# %%
sns.kdeplot(x='fnlwgt', data=df_c, shade=True)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %%
df_c.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %%
sns.boxplot(x='salary', y= 'fnlwgt', data=df_c)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='fnlwgt'>

# %%
sns.kdeplot(x='fnlwgt', data=df_c, hue='salary', shade=True);

# %%
df_c.groupby('salary')['fnlwgt'].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# # education_num

# %%
sns.boxplot(x='education_num', data=df_c);

plt.xlim(0)
# Out:
# (0.0, 16.75)

# %%
sns.kdeplot(x='education_num', data=df_c, shade=True)
# Out:
# <AxesSubplot:xlabel='education_num', ylabel='Density'>

# %%
df_c.education_num.describe()
# Out:
# count   31735.000
# mean       10.084
# std         2.575
# min         1.000
# 25%         9.000
# 50%        10.000
# 75%        12.000
# max        16.000
# Name: education_num, dtype: float64

# %%
sns.boxplot(x='salary', y= 'education_num', data=df_c)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='education_num'>

# %%
sns.kdeplot(x='fnlwgt', data=df_c, hue='salary', shade=True);

# %%
df_c.groupby('salary')['fnlwgt'].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# # capital_gain

# %%
sns.boxplot(x='capital_gain', data=df_c);

#plt.xlim(0)

# %%
sns.kdeplot(x='capital_gain', data=df_c, shade=True)
# Out:
# <AxesSubplot:xlabel='capital_gain', ylabel='Density'>

# %%
df_c.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %%
sns.boxplot(x='salary', y= 'capital_gain', data=df_c);

# %%
sns.kdeplot(x='capital_gain', data=df_c, hue='salary', shade=True);

# %%
df_c.groupby('salary')['capital_gain'].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# # capital_loss

# %%
sns.boxplot(x='capital_loss', data=df_c)
# Out:
# <AxesSubplot:xlabel='capital_loss'>

# %%
sns.kdeplot(x='capital_loss', data=df_c, shade=True);

# %%
df_c.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %%
sns.boxplot(x='salary', y= 'capital_loss', data=df_c);

# %%
sns.kdeplot(x='capital_loss', data=df_c, hue='salary', shade=True);

# %%
df_c.groupby('salary')['capital_loss'].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %%
capital_not_zero = df_c[df_c['capital_loss'] !=0]

# %%
capital_not_zero.groupby('salary')['capital_loss'].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# # hours_per_week

# %%
sns.boxplot(x='hours_per_week', data=df_c);

#plt.xlim(0)

# %%
sns.kdeplot(x='hours_per_week', data=df_c, shade=True)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Density'>

# %%
df_c.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %%
sns.boxplot(x='salary', y= 'hours_per_week', data=df_c)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='hours_per_week'>

# %%
sns.kdeplot(x='hours_per_week', data=df_c, hue='salary', shade=True);

# %%
df_c.groupby('salary')['hours_per_week'].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %%
sns.pairplot(data=df_c, palette='viridis', corner=True, diag_kind='kde', hue='salary');

# %% [markdown]
# # education & education_num

# %%
df_c.head(2)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital_status       occupation   relationship   race   sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K

# %%
df_c['education'].value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df_c['education_num'].value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df_c[['education_num']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   education_num  31735 non-null  float64
# dtypes: float64(1)
# memory usage: 1.5 MB

# %%
df_c[['education_num']].notna().value_counts()
# Out:
# education_num
# True             31735
# False              802
# dtype: int64

# %%
df_c[['education', 'education_num']].value_counts()
# Out:
# education     education_num
# HS-grad       9.000            10208
# Some-college  10.000            7089
# Bachelors     13.000            5245
# Masters       14.000            1686
# Assoc-voc     11.000            1343
# 11th          7.000             1146
# Assoc-acdm    12.000            1044
# 10th          6.000              916
# 7th-8th       4.000              630
# Prof-school   15.000             559
# 9th           5.000              503
# 12th          8.000              424
# Doctorate     16.000             405
# 5th-6th       3.000              329
# 1st-4th       2.000              159
# Preschool     1.000               49
# dtype: int64

# %%
df_c.groupby('education').education_num.value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %%
ax=sns.countplot(data=df_c, x= 'education');

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
sns.countplot(df_c.education_num);

# %%
edu_salary = df_c.groupby('education')['salary'].value_counts()
edu_salary
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
fig, ax = plt.subplots()

ax = sns.countplot(x ='education', hue='salary', data=df_c)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
df_c.groupby('education_num')['salary'].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
fig, ax = plt.subplots()

ax=sns.countplot(x='education_num', data=df_c, hue='salary')

# %%
fig, ax = plt.subplots()

ax= sns.boxplot(x='salary', y='education_num', data=df_c)

# %%
df_c['education'].unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
def education_level(x):
    if x in ['11th','9th','7th-8th','5th-6th','10th','1st-4th', 'Preschool', '12th']:
        return'low_level_grade'
    elif x in ['HS-grad','Some-college', 'Assoc-acdm', 'Assoc-voc']:
        return 'medium_level_grade'
    elif x in ['Bachelors', 'Masters', 'Doctorate', 'Prof-school']:
        return 'high_level_grade'

# %%
df_c['education'].apply(education_level).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
df_c['education_summary'] = df_c['education'].apply(education_level)

# %%
df_c
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
sns.countplot(x='education_summary', data=df_c)
# Out:
# <AxesSubplot:xlabel='education_summary', ylabel='count'>

# %%
df_c.groupby('education_summary')['salary'].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
sns.countplot(x='education_summary', data=df_c, hue='salary');

# %%
a=df_c.groupby('education_summary')['salary'].value_counts()/ df_c.groupby('education_summary')['salary'].count()*100

a
# Out:
# education_summary   salary
# high_level_grade    <=50K    51.525
#                     >50K     48.475
# low_level_grade     <=50K    94.256
#                     >50K      5.744
# medium_level_grade  <=50K    81.775
#                     >50K     18.225
# Name: salary, dtype: float64

# %%
a.index[1]
# Out:
# ('high_level_grade', '>50K')

# %%
a.index[2]
# Out:
# ('low_level_grade', '<=50K')

# %%
a.values[:2]
# Out:
# array([51.52529762, 48.47470238])

# %%
fig, (ax1, ax2, ax3) =plt.subplots(1,3, figsize=(17,10))

ax1.pie(a.values[:2], labels= df_c.salary.unique(), autopct='%0.2f%%', colors=['pink', 'lightskyblue']);
ax1.set_title('high_level_grade', fontsize=14)
ax1.set_ylabel('salary')

ax2.pie(a.values[2:4], labels= df_c.salary.unique(), autopct='%0.2f%%',  colors=['pink', 'lightskyblue']);
ax2.set_title('low_level_grade', fontsize=14)
ax2.set_ylabel('salary')

ax3.pie(a.values[4:6], labels= df_c.salary.unique(), autopct='%0.2f%%', colors=['pink', 'lightskyblue']);
ax3.set_title('medium_level_grade', fontsize=14)
ax3.set_ylabel('salary');

# %%
df_c.groupby('salary')['education_summary'].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
sns.countplot(x='salary', data=df_c, hue='education_summary');

# %%
df_c.groupby('salary')['education_summary'].count()
# Out:
# salary
# <=50K    24698
# >50K      7839
# Name: education_summary, dtype: int64

# %%
df_c.groupby('salary')['education_summary'].value_counts()/ df_c.groupby('salary')['education_summary'].count()
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
b=df_c.groupby('salary')['education_summary'].value_counts()/ df_c.groupby('salary')['education_summary'].count()

# %%
b.values[:3]
# Out:
# array([0.66964936, 0.16823225, 0.16211839])

# %%
b.index[3]
# Out:
# ('>50K', 'high_level_grade')

# %%
b.index[:1]
# Out:
# MultiIndex([('<=50K', 'medium_level_grade')],
#            names=['salary', 'education_summary'])

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols = 2,figsize=(15,6))

ax1.pie(b.values[:3], labels= [b.index[0], b.index[1], b.index[2]], autopct='%0.2f%%', colors=['pink', 'lightskyblue', 'lightgreen']);
ax1.set_title('<=50K', fontsize=14)
ax1.set_ylabel('education_summary');

ax2.pie(b.values[3:6], labels=[b.index[3], b.index[4], b.index[5]], autopct='%0.2f%%',  colors=['pink', 'lightskyblue', 'lightgreen']);
ax2.set_title('>50K', fontsize=14)
ax2.set_ylabel('education_summary');

# %%
df_c.groupby('salary')['education_summary'].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
df_c_percentage = df_c.groupby('salary').education_summary.value_counts(normalize=True).to_frame(name='percentage').reset_index().sort_values(by=['salary', 'education_summary'])
df_c_percentage
# Out:
#   salary   education_summary  percentage
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 0  <=50K  medium_level_grade       0.670
# 3   >50K    high_level_grade       0.499
# 5   >50K     low_level_grade       0.031
# 4   >50K  medium_level_grade       0.470

# %%
df_c_percentage["education_s"]=df_c_percentage.education_summary.str[:-12]
df_c_percentage
# Out:
#   salary   education_summary  percentage education_s
# 1  <=50K    high_level_grade       0.168        high
# 2  <=50K     low_level_grade       0.162         low
# 0  <=50K  medium_level_grade       0.670      medium
# 3   >50K    high_level_grade       0.499        high
# 5   >50K     low_level_grade       0.031         low
# 4   >50K  medium_level_grade       0.470      medium

# %%
df_c_percentage.reset_index(drop='Index')
# Out:
#   salary   education_summary  percentage education_s
# 0  <=50K    high_level_grade       0.168        high
# 1  <=50K     low_level_grade       0.162         low
# 2  <=50K  medium_level_grade       0.670      medium
# 3   >50K    high_level_grade       0.499        high
# 4   >50K     low_level_grade       0.031         low
# 5   >50K  medium_level_grade       0.470      medium

# %%
c=df_c_percentage.reset_index(drop='Index').loc[:2]
c.drop(columns='education_summary', inplace=True)

# %%
c
# Out:
#   salary  percentage education_s
# 0  <=50K       0.168        high
# 1  <=50K       0.162         low
# 2  <=50K       0.670      medium

# %%
c1=df_c_percentage.reset_index(drop='Index').loc[3:5]
c1.drop(columns='education_summary', inplace=True)
c1
# Out:
#   salary  percentage education_s
# 3   >50K       0.499        high
# 4   >50K       0.031         low
# 5   >50K       0.470      medium

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols = 2,figsize=(15,6))

ax1.pie(c.percentage, labels= c.education_s, autopct='%0.2f%%', colors=['pink','lightskyblue','lightgreen']);
ax1.set_title('<=50K', fontsize=14)
ax1.set_ylabel('percentage');

ax2.pie(c1.percentage, labels= c.education_s, autopct='%0.2f%%', colors=['pink','lightskyblue','lightgreen']);
ax2.set_title('>50K', fontsize=14)
ax2.set_ylabel('percentage');

# %% [markdown]
# # marital_status & relationship

# %%
df_c['marital_status'].value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df_c['relationship'].value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df_c.relationship.fillna('Unknown', inplace=True)
df_c.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_c.groupby('relationship').marital_status.value_counts(dropna=False)
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %%
ax=sns.countplot(data=df_c, x= 'marital_status');

ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
m_status_salary = df_c.groupby('marital_status')['salary'].value_counts()
m_status_salary
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots()

ax = sns.countplot(x ='marital_status', hue='salary', data=df_c)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
df_c['marital_status'].apply(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
df_c['marital_status_summary'] = df_c['marital_status'].apply(mapping_marital_status)
df_c.head(2)
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
#
#        marital_status       occupation   relationship   race   sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
#
#   education_summary marital_status_summary
# 0  high_level_grade              unmarried
# 1  high_level_grade                married

# %%
sns.countplot(x='marital_status_summary', data=df_c)
# Out:
# <AxesSubplot:xlabel='marital_status_summary', ylabel='count'>

# %%
df_c.groupby('marital_status_summary')['salary'].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
sns.countplot(x='marital_status_summary', data=df_c, hue='salary');

# %%
a=df_c.groupby('marital_status_summary')['salary'].value_counts()/ df_c.groupby('marital_status_summary')['salary'].count()

a
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
fig, (ax1, ax2) =plt.subplots(1,2 ,figsize=(12,12))

ax1.pie(a.values[:2], labels= df_c.salary.unique(), autopct='%0.2f%%', colors=['pink', 'lightskyblue']);
ax1.set_title('married', fontsize=14)
ax1.set_ylabel('salary')

ax2.pie(a.values[2:4], labels= df_c.salary.unique(), autopct='%0.2f%%',  colors=['pink', 'lightskyblue']);
ax2.set_title('umarried', fontsize=14)
ax2.set_ylabel('salary');

# %%
df_c.groupby('salary')['marital_status_summary'].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(x='salary', data=df_c, hue='marital_status_summary');

# %%
df_c.groupby('salary')['marital_status_summary'].count()
# Out:
# salary
# <=50K    24698
# >50K      7839
# Name: marital_status_summary, dtype: int64

# %%
df_c.groupby('salary')['marital_status_summary'].value_counts()/ df_c.groupby('salary')['marital_status_summary'].count()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
b=df_c.groupby('salary')['marital_status_summary'].value_counts()/ df_c.groupby('salary')['marital_status_summary'].count()

# %%
df_c.groupby('salary')['marital_status_summary'].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df_c_percentage = df_c.groupby('salary').marital_status_summary.value_counts(normalize=True).to_frame(name='percentage').reset_index().sort_values(by=['salary', 'marital_status_summary'])
df_c_percentage
# Out:
#   salary marital_status_summary  percentage
# 1  <=50K                married       0.351
# 0  <=50K              unmarried       0.649
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
df_c_percentage.reset_index(drop='Index')
# Out:
#   salary marital_status_summary  percentage
# 0  <=50K                married       0.351
# 1  <=50K              unmarried       0.649
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
c=df_c_percentage.reset_index(drop='Index').loc[:1]
c
# Out:
#   salary marital_status_summary  percentage
# 0  <=50K                married       0.351
# 1  <=50K              unmarried       0.649

# %%
c1=df_c_percentage.reset_index(drop='Index').loc[2:3]
c1
# Out:
#   salary marital_status_summary  percentage
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols = 2,figsize=(15,6))

ax1.pie(c.percentage, labels= c.marital_status_summary, autopct='%0.2f%%', colors=['pink','lightskyblue','lightgreen']);
ax1.set_title('<=50K', fontsize=14)
ax1.set_ylabel('percentage');

ax2.pie(c1.percentage, labels= c1.marital_status_summary, autopct='%0.2f%%', colors=['pink','lightskyblue','lightgreen']);
ax2.set_title('>50K', fontsize=14)
ax2.set_ylabel('percentage');

# %% [markdown]
# # Workclass

# %%
df_c.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_c['workclass'].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
ax=sns.countplot(data=df_c, x= 'workclass');

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
df_c.workclass.replace(to_replace=r'?', value='Unknown',inplace=True)

# %%
workclass_salary = df_c.groupby('workclass')['salary'].value_counts()
workclass_salary
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots()

ax = sns.countplot(x ='workclass', hue='salary', data=df_c)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
workclass_salary/df_c.groupby('workclass')['salary'].count()
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
df_c_percentage = df_c.groupby('workclass')['salary'].value_counts(normalize=True).to_frame(name='percentage').reset_index().sort_values(by=['workclass', 'salary'])
df_c_percentage
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 8       Self-emp-inc  <=50K       0.443
# 7       Self-emp-inc   >50K       0.557
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
ax=sns.barplot(x='workclass', y='percentage', data=df_c_percentage, hue='salary')

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
df_c.groupby('salary')['workclass'].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
sns.countplot(x='salary', data=df_c, hue='workclass');

# %%
df_c.groupby('salary')['workclass'].value_counts()/ df_c.groupby('salary')['workclass'].count()
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
df_c_percentage = df_c.groupby('salary')['workclass'].value_counts(normalize=True).to_frame(name='percentage').reset_index().sort_values(by=['workclass', 'salary'])
df_c_percentage
# Out:
#    salary         workclass  percentage
# 5   <=50K       Federal-gov       0.024
# 13   >50K       Federal-gov       0.047
# 3   <=50K         Local-gov       0.060
# 12   >50K         Local-gov       0.079
# 8   <=50K      Never-worked       0.000
# 0   <=50K           Private       0.717
# 9    >50K           Private       0.633
# 6   <=50K      Self-emp-inc       0.020
# 11   >50K      Self-emp-inc       0.079
# 1   <=50K  Self-emp-not-inc       0.074
# 10   >50K  Self-emp-not-inc       0.092
# 4   <=50K         State-gov       0.038
# 14   >50K         State-gov       0.045
# 2   <=50K           Unknown       0.067
# 15   >50K           Unknown       0.024
# 7   <=50K       Without-pay       0.001

# %%
sns.barplot(x='salary', y='percentage', data=df_c_percentage, hue='workclass');

# %% [markdown]
# # occupation

# %%
df_c.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
ax=sns.countplot(data=df_c, x= 'workclass');

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
df_c.occupation.replace(to_replace=r'?', value='Unknown',inplace=True)

# %%
df_c.groupby('occupation').salary.value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
ax=sns.countplot(data=df_c, x= 'occupation', hue='salary');

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
df_c.groupby("occupation").salary.value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
df_c_percentage = df_c.groupby("occupation").salary.value_counts(normalize=True).to_frame(
                    name='percentage').reset_index().sort_values(by=['occupation', 'salary'])

# %%
df_c_percentage
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
# Your Code is Here

fig, ax=plt.subplots()

ax=sns.barplot(x="occupation", y="percentage", hue="salary", data=df_c_percentage)

plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))
    
# for i in ax.containers :
#     ax.bar_label(i,fmt='%.2f', fontsize=10)

# %%
df_c.groupby("salary").occupation.value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
sns.countplot(data=df_c, hue='occupation', x='salary');

#plt.xticks(rotation=90);

# %%
df_c.groupby("salary").occupation.value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
df_c_percentage = df_c.groupby('salary').occupation.value_counts(normalize=True).to_frame(
                    name='percentage').reset_index().sort_values(by=['salary','occupation'])

# %%
fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(x="salary", y="percentage", hue="occupation", data=df_c_percentage, ax=ax)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# # race

# %%
df_c.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='race', data=df_c)


plt.xticks(rotation=45);

# %%
df_c.groupby('race').salary.value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='race', hue='salary', data=df_c, ax=ax)

plt.xticks(rotation=45);

# %%
df_c.groupby('race').salary.value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
df_race=df_c.groupby("race").salary.value_counts(normalize=True).to_frame().unstack(0)
df_race
# Out:
#                    salary
# race   Amer-Indian-Eskimo Asian-Pac-Islander Black Other White
# salary
# <=50K               0.884              0.734 0.876 0.908 0.744
# >50K                0.116              0.266 0.124 0.092 0.256

# %%
df_race.plot.pie(
    subplots=True, layout=(2,3),
    legend=False,
    colors=["pink","lightskyblue"],
    autopct='%.2f%%',
    ylabel= "salary",
    title=["Amer-Indian-Eskimo","Asian-Pac-Islander","Black","Other","White"],
    textprops={'fontsize':16, 'color':'k'},
    figsize=(18,8));
 
plt.tight_layout()

# %%
df_c.groupby("salary").race.value_counts()
# Out:
# salary  race
# <=50K   White                 20699
#         Black                  2737
#         Asian-Pac-Islander      763
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7117
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='race', hue='salary', data=df_c, ax=ax)
    


plt.xticks(rotation=90);

# %%
df_c.groupby("salary").race.value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
df_c_percentage = df_c.groupby('salary').race.value_counts(normalize=True).to_frame(
                    name='percentage').reset_index().sort_values(by=['salary','race'])

# %%
fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(x="salary", y="percentage", hue="race", data=df_c_percentage, ax=ax)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# # sex

# %%
df_c.groupby('sex').salary.value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='sex', data=df_c, hue='salary', ax=ax)
    

plt.xticks(rotation=90);

# %%
df_c.groupby("sex").salary.value_counts(normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
df_gen_sal_per = df_c.groupby("sex").salary.value_counts(normalize=True).to_frame().unstack(0)
df_gen_sal_per
# Out:
#        salary
# sex    Female  Male
# salary
# <=50K   0.890 0.694
# >50K    0.110 0.306

# %%
df_gen_sal_per.plot.pie(
                    subplots=True, layout=(1,2),
                    legend=False,
                    colors=["pink","lightskyblue"],
                    autopct='%.2f%%',
                    ylabel= "salary",
                    title=["Female", "Male"],
                    textprops={'fontsize':16, 'color':'k'},
                    figsize=(14,6));
 
plt.tight_layout()

# %%
df_c.groupby("salary").sex.value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='salary', hue='sex', data=df_c, ax=ax)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
df_c.groupby("salary").sex.value_counts(normalize=True)

# %%
df_sal_gen_count_per = df_c.groupby("salary").sex.value_counts(normalize=True).to_frame().unstack(0)
df_sal_gen_count_per
# Out:
#          sex
# salary <=50K  >50K
# sex
# Female 0.388 0.150
# Male   0.612 0.850

# %%
df_sal_gen_count_per.plot.pie(
                    subplots=True, layout=(1,2),
                    legend=False,
                    colors=["lightskyblue","pink"],
                    autopct='%.2f%%',
                    ylabel= "salary",
                    title=["<=50K",">50K"],
                    textprops={'fontsize':16, 'color':'k'},
                    figsize=(14,6),
                    startangle=220)
 
plt.tight_layout()

# %% [markdown]
# # native_country

# %%
df_c.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='native_country', data=df_c, ax=ax)
    
plt.xticks(rotation=90);

# %%
df_c.native_country.replace(to_replace=r'?', value='Unknown',inplace=True)

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
df_c.native_country.apply(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
df_c['native_country_summary'] = df_c.native_country.transform(mapping_native_country)
df_c['native_country_summary']
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='native_country_summary', data=df_c, ax=ax)
# Out:
# <AxesSubplot:xlabel='native_country_summary', ylabel='count'>

# %%
df_c.groupby("native_country_summary").salary.value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.countplot(x='native_country_summary', hue='salary', data=df_c, ax=ax)
    
plt.xticks(rotation=90);

# %%
df_c.groupby("native_country_summary").salary.value_counts(normalize=True)

# %%
df_edu_salary_count_per = df_c.groupby("native_country_summary").salary.value_counts(normalize=True).to_frame().unstack(0)
df_edu_salary_count_per
# Out:
#                        salary
# native_country_summary Others    US
# salary
# <=50K                   0.802 0.754
# >50K                    0.198 0.246

# %%
df_edu_salary_count_per.plot.pie(
                    subplots=True, layout=(1,2),
                    legend=False,
                    colors=["pink","lightskyblue"],
                    autopct='%.2f%%',
                    ylabel= "salary",
                    title=["Others", "US"],
                    textprops={'fontsize':16, 'color':'k'},
                    figsize=(14,6));
 
plt.tight_layout()

# %%
df_c.groupby("salary").native_country_summary.value_counts()

# %%
fig, ax = plt.subplots(figsize=(10,8))

sns.countplot(x='salary', data=df_c, hue='native_country_summary', ax=ax)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
df_c.groupby("salary").native_country_summary.value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
df_sal_nat_count_per = df_c.groupby("salary").native_country_summary.value_counts(normalize=True).to_frame().unstack(0)
df_sal_nat_count_per
# Out:
#                        native_country_summary
# salary                                  <=50K  >50K
# native_country_summary
# Others                                  0.110 0.085
# US                                      0.890 0.915

# %%
df_sal_nat_count_per.plot.pie(
                    subplots=True, layout=(1,2),
                    legend=False,
                    colors=["lightskyblue","pink"],
                    autopct='%.2f%%',
                    ylabel= "native_country_summary",
                    title=["Others", "US"],
                    textprops={'fontsize':16, 'color':'k'},
                    figsize=(14,6),
                    startangle=320)
 
plt.tight_layout()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
df_c.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_age_mean= df_c.groupby(['salary','sex'])['age'].mean()

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(10,8))

ax = df_age_mean.plot.bar(ax=ax)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %%
df_1 = df_c.groupby(["salary","sex"])["age"].mean().to_frame().reset_index().sort_values(by=['salary','sex'])
df_1
# Out:
#   salary     sex    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
# Your Code is Here

fig, ax = plt.subplots(figsize=(10,8))

sns.barplot(x="salary", y="age", hue="sex", data=df_1, ax=ax)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df_high_work = df_c.loc[ (df_c["salary"] == ">50K") & (df_c["native_country"]=="United-States"
                            )]["workclass"].value_counts(normalize=True)*100
df_high_work
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(x=df_high_work.index, y=df_high_work.values, ax=ax)

plt.xticks(rotation=45)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df_high_occ_per = df_c.loc[ (df_c["salary"] == ">50K") & (df_c["native_country"]=="United-States")
                    & (df_c["workclass"] == "Private")]["occupation"].value_counts(normalize=True)*100
df_high_occ_per
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Protective-serv      0.595
# Farming-fishing      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(x=df_high_occ_per.index, y=df_high_occ_per.values, ax=ax)

plt.xticks(rotation=90)


for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df_high_edu_per = df_c.loc[ (df_c["salary"] == ">50K") & (df_c["race"]=="Asian-Pac-Islander")
                           ]["education"].value_counts(normalize=True)*100
df_high_edu_per
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 12th            0.362
# 10th            0.362
# Name: education, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(x=df_high_edu_per.index, y=df_high_edu_per.values, ax=ax)

plt.xticks(rotation=90)


for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
df_high_occ_edu_per = df_c.loc[ (df_c["salary"] == ">50K") & (df_c["race"]=="Asian-Pac-Islander")
            & (df_c["education"] == "Bachelors")]["occupation"].value_counts(normalize=True)*100
df_high_occ_edu_per
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Other-service        9.278
# Sales                9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Farming-fishing      1.031
# Machine-op-inspct    1.031
# Transport-moving     1.031
# Name: occupation, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(x=df_high_occ_edu_per.index, y=df_high_occ_edu_per.values, ax=ax)

plt.xticks(rotation=90)


for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x(), p.get_height()))

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here

g = sns.catplot(x="education_summary",y="hours_per_week",
                data=df_c,hue="sex",
                row="native_country_summary",col="marital_status_summary",
                ci=None,kind="bar",
                height=8, aspect=1,
                palette=["pink","skyblue"]);

for ax in g.axes.ravel():
    for p in ax.patches:
        ax.annotate((p.get_height()),(p.get_x(), p.get_height()))
        
g.fig.suptitle("working hours per week by gender for education level, workclass and marital \
status".title(), y = 1.02, fontsize=20);

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
df_c.drop(columns=["education", "education_num", "relationship", "marital_status", "native_country"], inplace=True)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df_c.head(2)
# Out:
#    age         workclass  fnlwgt       occupation   race   sex  capital_gain  \
# 0   39         State-gov   77516     Adm-clerical  White  Male          2174
# 1   50  Self-emp-not-inc   83311  Exec-managerial  White  Male             0
#
#    capital_loss  hours_per_week salary education_summary  \
# 0             0              40  <=50K  high_level_grade
# 1             0              13  <=50K  high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# 1                married                     US

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              32537 non-null  object
#  4   race                    32537 non-null  object
#  5   sex                     32537 non-null  object
#  6   capital_gain            32537 non-null  int64
#  7   capital_loss            32537 non-null  int64
#  8   hours_per_week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  education_summary       32537 non-null  object
#  11  marital_status_summary  32537 non-null  object
#  12  native_country_summary  32537 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 4.5+ MB

# %%
df_c.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
df_c["workclass"].value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df_c["occupation"].value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df_c.loc[ (df_c["workclass"]=='Unknown') | (df_c["workclass"]=='Never-worked') 
                                      ]["workclass"].value_counts(dropna=False)
# Out:
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
df_c["workclass"].replace(to_replace="Unknown", value=np.nan, inplace=True)
df_c["occupation"].replace(to_replace="Unknown", value=np.nan, inplace=True)

# %%
df_c[ df_c == 'Unknown'].count()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df_c[ df_c == 'Unknown'].count()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               30701 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    32537 non-null  object
#  5   sex                     32537 non-null  object
#  6   capital_gain            32537 non-null  int64
#  7   capital_loss            32537 non-null  int64
#  8   hours_per_week          32537 non-null  int64
#  9   salary                  32537 non-null  object
#  10  education_summary       32537 non-null  object
#  11  marital_status_summary  32537 non-null  object
#  12  native_country_summary  32537 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 4.5+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
sns.boxplot(data=df_c, orient='v');

# %%
df_c.plot.box(subplots=True, layout=(2,3), vert=True)
# Out:
# age                  AxesSubplot(0.125,0.536818;0.227941x0.343182)
# fnlwgt            AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# capital_gain      AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# capital_loss            AxesSubplot(0.125,0.125;0.227941x0.343182)
# hours_per_week       AxesSubplot(0.398529,0.125;0.227941x0.343182)
# dtype: object

# %%
df_num = df_c.select_dtypes(include=np.number)
fig, ax = plt.subplots(nrows=2, ncols=3,figsize=(20,10))
i = j = 0
for z in df_num.columns:
    g = sns.boxplot(data=df_num[z], ax=ax[i][j],orient="h")
    g.set(xlabel = z)
    g.set_yticklabels("")
    j += 1
    if j>2:
        i += 1; j = 0

# %%
df_num = df_c.select_dtypes(include=np.number)

fig, ax = plt.subplots(nrows=5, ncols=2,figsize=(10,15))
i = j = 0

for z in df_num.columns:
    g = sns.boxplot(data=df_num[z], ax=ax[i][j],orient="h")
    g.set(xlabel = z)
    g.set_yticklabels("")
    j+=1
    sns.histplot(data=df_num[z], ax=ax[i][j])
    j=0 
    i += 1
    
plt.tight_layout()

# %%
df_c.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# capital_gain   32537.000   1078.444   7387.957     0.000      0.000
# capital_loss   32537.000     87.368    403.102     0.000      0.000
# hours_per_week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# # age

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))

sns.boxplot(data=df_c["age"], ax=ax[0])
sns.histplot(data=df_c["age"], ax=ax[1]) 

plt.tight_layout()

# %%
q1 = df_c["age"].quantile(0.25)
q3 = df_c["age"].quantile(0.75)
iqr = q3 - q1

q1,q3,iqr
# Out:
# (28.0, 48.0, 20.0)

# %%
from scipy import stats

# %%
np.percentile(df_c["age"],25), np.percentile(df_c["age"],75), stats.iqr(df_c["age"])
# Out:
# (28.0, 48.0, 20.0)

# %%
lower_lim = q1 - (1.5*iqr)
upper_lim = q3 + (1.5*iqr)
lower_lim, upper_lim
# Out:
# (32.5, 52.5)

# %%
df_c.loc[ df_c["age"]>upper_lim ]["age"].value_counts()
# Out:
# 53    464
# 55    419
# 54    415
# 58    366
# 56    366
# 57    358
# 59    355
# 60    312
# 61    300
# 62    258
# 63    230
# 64    208
# 65    178
# 67    151
# 66    150
# 68    120
# 69    108
# 70     89
# 71     72
# 72     67
# 73     64
# 74     51
# 76     46
# 75     45
# 90     42
# 77     29
# 78     23
# 80     22
# 79     22
# 81     20
# 82     12
# 84     10
# 83      6
# 85      3
# 88      3
# 86      1
# 87      1
# Name: age, dtype: int64

# %%
df_c.loc[ df_c["age"]>upper_lim ].sort_values(by="age",ascending=False)
# Out:
#        age  workclass  fnlwgt         occupation                race     sex  \
# 11996   90    Private   40388    Exec-managerial               White    Male
# 18725   90  Local-gov  153602      Other-service               White    Male
# 222     90    Private   51744      Other-service               Black    Male
# 14159   90  Local-gov  187749       Adm-clerical  Asian-Pac-Islander    Male
# 1935    90    Private  221832    Exec-managerial               White    Male
# ...    ...        ...     ...                ...                 ...     ...
# 26318   53    Private  139127      Other-service               White  Female
# 26334   53    Private  215572       Craft-repair               White    Male
# 8764    53        NaN   29231                NaN               White    Male
# 8730    53    Private   31460     Prof-specialty               White    Male
# 3       53    Private  234721  Handlers-cleaners               Black    Male
#
# ...

# %% [markdown]
# # Hours_per_week

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))

sns.boxplot(data=df_c["hours_per_week"], ax=ax[0])
sns.histplot(data=df_c["hours_per_week"], ax=ax[1]) 

plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
q1 = df_c["hours_per_week"].quantile(0.25)
q3 = df_c["hours_per_week"].quantile(0.75)
iqr = q3 - q1

q1,q3,iqr
# Out:
# (40.0, 45.0, 5.0)

# %%
np.percentile(df_c["hours_per_week"],25), np.percentile(df_c["hours_per_week"],75), stats.iqr(df_c["hours_per_week"])
# Out:
# (40.0, 45.0, 5.0)

# %%
lower_lim = q1 - (1.5*iqr)
upper_lim = q3 + (1.5*iqr)
lower_lim, upper_lim
# Out:
# (32.5, 52.5)

# %%
df_c.loc[ df_c["hours_per_week"]>upper_lim ]["hours_per_week"].value_counts().sort_index(ascending=False)
# Out:
# 99      85
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      29
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      45
# 82       1
# 81       3
# 80     133
# 78       8
# 77       6
# 76       3
# 75      66
# 74       1
# 73       2
# 72      71
# 70     291
# 68      12
# 67       4
# 66      17
# 65     244
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1475
# 59       5
# 58      28
# 57      17
# 56      97
# 55     693
# 54      41
# 53      25
# Name: hours_per_week, dtype: int64

# %%
df_c.loc[ df_c["hours_per_week"]>upper_lim ].sort_values(by="hours_per_week",ascending=False)
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 25986   44         Local-gov  212665    Protective-serv  Black    Male
# 23179   31           Private  511289    Farming-fishing  White    Male
# 13558   38           Private  191103     Prof-specialty  White    Male
# 9831    67           Private   35015     Prof-specialty  White    Male
# 13580   38  Self-emp-not-inc  112158    Exec-managerial  White    Male
# ...    ...               ...     ...                ...    ...     ...
# 23244   58           Private  248739    Farming-fishing  White    Male
# 15908   22         Local-gov  163205      Other-service  White  Female
# 5345    30           Private  140011  Handlers-cleaners  White    Male
# 15889   43       Federal-gov  155106  Handlers-cleaners  White    Male
# 5864    48           Private  348144   Transport-moving  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
df_c[(df_c["hours_per_week"] < lower_lim)]["hours_per_week"].value_counts().sort_index()
# Out:
# 1       20
# 2       32
# 3       39
# 4       54
# 5       60
# 6       64
# 7       26
# 8      145
# 9       18
# 10     275
# 11      11
# 12     173
# 13      23
# 14      33
# 15     404
# 16     205
# 17      29
# 18      75
# 19      14
# 20    1224
# 21      24
# 22      44
# 23      21
# 24     252
# 25     674
# 26      30
# 27      30
# 28      86
# 29       7
# 30    1148
# 31       5
# 32     266
# Name: hours_per_week, dtype: int64

# %%
df_c[(df_c["hours_per_week"] < lower_lim)].sort_values(by="hours_per_week", ascending=False)
# Out:
#        age     workclass  fnlwgt         occupation   race     sex  \
# 16379   20           NaN  347292                NaN  White    Male
# 12422   17       Private  413557       Adm-clerical  White  Female
# 30426   56  Self-emp-inc   75214     Prof-specialty  White    Male
# 23414   36       Private  334366    Exec-managerial  White  Female
# 30494   27       Private  150296      Other-service  White  Female
# ...    ...           ...     ...                ...    ...     ...
# 22960   21       Private  184135  Machine-op-inspct  Black    Male
# 29752   69           NaN  117525                NaN  White  Female
# 5632    45           NaN  189564                NaN  White  Female
# 23536   69           NaN  320280                NaN  White    Male
# 1262    69           NaN  195779                NaN  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 16379             0             0              32  <=50K  medium_level_grade
# ...

# %%
df_c.loc[ (df_c["hours_per_week"]<lower_lim)].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  5130.000 21.128 7.665 1.000 16.000 20.000 30.000 32.000
# >50K    381.000 21.045 8.464 1.000 15.000 20.000 30.000 32.000

# %%
df_c[(df_c["hours_per_week"] < lower_lim)].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  5130.000 35.162 18.691 17.000 20.000 26.000 48.000 90.000
# >50K    381.000 50.759 14.384 22.000 39.000 50.000 62.000 90.000

# %%
df_c.loc[ df_c["age" ]>80 ]
# Out:
#        age         workclass  fnlwgt       occupation   race     sex  \
# 222     90           Private   51744    Other-service  Black    Male
# 918     81  Self-emp-not-inc  136063  Exec-managerial  White    Male
# 1040    90           Private  137018    Other-service  White  Female
# 1168    88  Self-emp-not-inc  206291   Prof-specialty  White    Male
# 1935    90           Private  221832  Exec-managerial  White    Male
# ...    ...               ...     ...              ...    ...     ...
# 32277   90           Private  313749     Adm-clerical  White  Female
# 32367   90         Local-gov  214594  Protective-serv  White    Male
# 32459   85           Private   98611  Exec-managerial  White    Male
# 32494   82               NaN  403910              NaN  White    Male
# 32525   81               NaN  120478              NaN  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
df_c.loc[ df_c["age" ]>80 ].shape
# Out:
# (98, 13)

# %%
df_c.loc[ df_c["age" ]>80 ].index
# Out:
# Int64Index([  222,   918,  1040,  1168,  1935,  2303,  2891,  2906,  3211,
#              3537,  3963,  4070,  4109,  4834,  5272,  5370,  5406,  6214,
#              6232,  6624,  6748,  7481,  7720,  7872,  8381,  8431,  8806,
#              8963,  8973,  9471, 10210, 10545, 11238, 11512, 11731, 11996,
#             12451, 12492, 12830, 12975, 13025, 13295, 13696, 13928, 14159,
#             14711, 14756, 15356, 15662, 15892, 16302, 16762, 18277, 18413,
#             18725, 18832, 19045, 19172, 19180, 19212, 19489, 19495, 19747,
#             20421, 20463, 20610, 20826, 21501, 21812, 21835, 22220, 22481,
#             22895, 22898, 23459, 24027, 24043, 24238, 24280, 24395, 24560,
#             25303, 26012, 26731, 27795, 28463, 28948, 29594, 29724, 31030,
#             31432, 31696, 31855, 32277, 32367, 32459, 32494, 32525],
#            dtype='int64')

# %%
df_c.drop( index=df_c[df_c["age"]>80].index,inplace=True )

# %%
df_c[(df_c["hours_per_week"]>70) | (df_c["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 32531   30               NaN   33811              NaN  Asian-Pac-Islander
# 22313   26  Self-emp-not-inc  258306  Farming-fishing               White
# 20036   61      Self-emp-inc  102191  Exec-managerial               White
# 4441    43      Self-emp-inc  286750   Prof-specialty               Black
# 11833   58           Private  164857   Prof-specialty               White
# ...    ...               ...     ...              ...                 ...
# 9147    75               NaN  260543              NaN  Asian-Pac-Islander
# 5808    76               NaN  211574              NaN               White
# 25078   74           Private  260669    Other-service               White
# 5766    62               NaN   97231              NaN               White
# 24284   57  Self-emp-not-inc   56480  Exec-managerial               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %%
df_c[(df_c["hours_per_week"]>70) | (df_c["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False).shape
# Out:
# (753, 13)

# %%
df_c[(df_c["hours_per_week"]>70) | (df_c["hours_per_week"]<7)].sort_values(by='hours_per_week',ascending=False).index
# Out:
# Int64Index([32531, 22313, 20036,  4441, 11833,  4308,  8393, 21056, 21147,
#             10986,
#             ...
#              5590, 22960, 19337,  1262, 23536,  9147,  5808, 25078,  5766,
#             24284],
#            dtype='int64', length=753)

# %%
df_c.drop(index=df_c[(df_c["hours_per_week"]>70) | (df_c["hours_per_week"]<7)].index, inplace=True)

# %%
df_c.loc[ (df_c['age']>60) & (df_c['hours_per_week']>60) ]
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 2154    75           Private  101887   Priv-house-serv               White
# 2184    63      Self-emp-inc   54052             Sales               White
# 2665    70           Private   94692             Sales               White
# 3101    65      Self-emp-inc   81413   Farming-fishing               White
# 5417    67           Private  197816             Sales               White
# 6826    68           Private  284763  Transport-moving               White
# 8066    61  Self-emp-not-inc  133969             Sales  Asian-Pac-Islander
# 9646    62  Self-emp-not-inc   26911     Other-service               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 16634   62  Self-emp-not-inc  115176   Farming-fishing               White
# ...

# %%
df_c.loc[ (df_c['age']>60) & (df_c['hours_per_week']>60) ].shape
# Out:
# (27, 13)

# %%
df_c.loc[ (df_c['age']>60) & (df_c['hours_per_week']>60) ].index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 20576, 21631, 23399, 23585,
#             24903, 25910, 26625, 27507, 27721, 28294, 29360, 31342, 32192],
#            dtype='int64')

# %%
df_c.drop(index=df_c.loc[ (df_c['age']>60) & (df_c['hours_per_week']>60) ].index, inplace=True)

# %%
df_c.shape
# Out:
# (31659, 13)

# %%
df_c.reset_index(drop=True, inplace=True)
df_c.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %%
df_c['salary'] = df_c.salary.map({'<=50K': 0, '>50K': 1})
df_c['salary']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31654    0
# 31655    1
# 31656    0
# 31657    0
# 31658    1
# Name: salary, Length: 31659, dtype: int64

# %%
df_c['salary'].value_counts()
# Out:
# 0    24037
# 1     7622
# Name: salary, dtype: int64

# %%
pd.get_dummies(df_c, drop_first=True)
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week  salary  \
# 0       39   77516          2174             0              40       0
# 1       50   83311             0             0              13       0
# 2       38  215646             0             0              40       0
# 3       53  234721             0             0              40       0
# 4       28  338409             0             0              40       0
# ...    ...     ...           ...           ...             ...     ...
# 31654   27  257302             0             0              38       0
# 31655   40  154374             0             0              40       1
# 31656   58  151910             0             0              40       0
# 31657   22  201490             0             0              20       0
# 31658   52  287927         15024             0              40       1
#
#        workclass_Local-gov  workclass_Never-worked  workclass_Private  \
# ...

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
pd.get_dummies(df_c, drop_first=True).corr()
# Out:
#                                         age  fnlwgt  capital_gain  \
# age                                   1.000  -0.074         0.080
# fnlwgt                               -0.074   1.000        -0.002
# capital_gain                          0.080  -0.002         1.000
# capital_loss                          0.056  -0.011        -0.032
# hours_per_week                        0.101  -0.016         0.085
# salary                                0.248  -0.010         0.223
# workclass_Local-gov                   0.065  -0.004        -0.009
# workclass_Never-worked               -0.018   0.006        -0.002
# workclass_Private                    -0.192   0.040        -0.036
# workclass_Self-emp-inc                0.104  -0.024         0.093
# workclass_Self-emp-not-inc            0.135  -0.036         0.034
# workclass_State-gov                   0.018  -0.012        -0.012
# workclass_Without-pay                 0.015  -0.003        -0.002
# ...

# %%
# Your Code is Here

plt.figure(figsize=(14,20))

sns.heatmap(pd.get_dummies(df_c, drop_first=True).corr(), annot=True, cmap='YlGnBu', annot_kws={'fontsize':8})
# Out:
# <AxesSubplot:>

# %%
# Your Code is Here

df_sal_corr = pd.get_dummies(df_c, drop_first=True).corr()[['salary']].sort_values(by='salary', ascending=False)[1:]
df_sal_corr
# Out:
#                                       salary
# hours_per_week                         0.249
# age                                    0.248
# capital_gain                           0.223
# occupation_Exec-managerial             0.218
# sex_Male                               0.216
# occupation_Prof-specialty              0.188
# capital_loss                           0.152
# workclass_Self-emp-inc                 0.139
# race_White                             0.087
# workclass_Self-emp-not-inc             0.035
# native_country_summary_US              0.034
# workclass_Local-gov                    0.033
# occupation_Protective-serv             0.028
# occupation_Tech-support                0.026
# occupation_Sales                       0.021
# workclass_State-gov                    0.014
# race_Asian-Pac-Islander                0.011
# occupation_Armed-Forces               -0.005
# workclass_Never-worked                -0.008
# fnlwgt                                -0.010
# ...

# %%
# Your Code is Here

plt.figure(figsize=(3,12))

sns.heatmap(df_sal_corr, annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
# Your Code is Here

plt.figure(figsize=(5,10))

sns.barplot(y=df_sal_corr.index, x=df_sal_corr.salary, color='royalblue');

# %%
df_sal_corr[::-1].plot.barh(figsize=(5,13), legend=False);

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
